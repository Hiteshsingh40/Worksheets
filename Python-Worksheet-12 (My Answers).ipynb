# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Data Visualization Libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Check for Outliers and Skewness(0 > log transform; 0.5 > square root transform)
from scipy.stats import zscore, boxcox

# %%
#Import dataset
df=pd.read_csv('data.csv')
df
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %% [markdown]
# ### Ans1. Determine the no. of rows and no. of columns in the dataset

# %%
df.shape
# Out:
# (23678, 21)

# %% [markdown]
# ### Ans2. Display the datatypes of each column.

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms            float64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %% [markdown]
# ### Ans3. Determine the row indexes of rows having all null values (i.e. empty rows).

# %%
d= df.loc[df.isnull().sum(axis=1)>20]

# %%
d
# Out:
#       Suburb Address  Rooms Type  Price Method SellerG Date  Distance  \
# 31       NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 1145     NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 1348     NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 2119     NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 3277     NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# ...      ...     ...    ...  ...    ...    ...     ...  ...       ...
# 22288    NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 22704    NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 22918    NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 23153    NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
# 23341    NaN     NaN    NaN  NaN    NaN    NaN     NaN  NaN       NaN
#
#        Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# ...

# %%
d.shape
# Out:
# (131, 21)

# %% [markdown]
# Finding:-
#     131 rows having all null value.

# %% [markdown]
# ### Ans4. Determine the total number of empty rows and their percentage in whole dataset and remove them

# %%
df1=df.copy()

# %%
df1.shape
# Out:
# (23678, 21)

# %%
df1.dropna(how='all').shape
# Out:
# (23547, 21)

# %%
df1.shape
# Out:
# (23678, 21)

# %%
23678-23547
# Out:
# 131

# %%
(131/23678)*100
# Out:
# 0.5532561871779711

# %% [markdown]
# 0.55% empty rows in the datasets.

# %%
df1.dropna(how='all',inplace=True)

# %%
df1.shape
# Out:
# (23547, 21)

# %% [markdown]
# ### Ans5. Determine the column names having missing values.

# %%
df1.columns[df1.isnull().any()]
# Out:
# Index(['Price', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# ### Ans6. Determine the missing values and their percentage in each column.

# %%
df1.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
(df1.isnull().sum()/len(df1))*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            21.875398
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.004247
# Postcode          0.004247
# Bedroom2         19.030025
# Bathroom         19.042766
# Car              19.645815
# Landsize         26.062768
# BuildingArea     57.455302
# YearBuilt        50.991634
# CouncilArea      33.511700
# Lattitude        18.278337
# Longtitude       18.278337
# Regionname        0.004247
# Propertycount     0.004247
# dtype: float64

# %% [markdown]
# ### Ans7. Determine the row indexes having missing values.

# %%
Row_Missing= df1.loc[df1.isnull().sum(axis=1)>0]

# %%
Row_Missing
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 5        Abbotsford    40 Federation La    3.0    h   850000.0     PI
# 7        Abbotsford        16 Maugie St    4.0    h        NaN     SN
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %% [markdown]
# Finding:-
#     17351 rows having missing value.

# %% [markdown]
# ### Ans8. Determine the missing values and their percentage in each row.

# %%
df1.isnull()
# Out:
#        Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0       False    False  False  False   True   False    False  False     False
# 1       False    False  False  False  False   False    False  False     False
# 2       False    False  False  False  False   False    False  False     False
# 3       False    False  False  False   True   False    False  False     False
# 4       False    False  False  False  False   False    False  False     False
# ...       ...      ...    ...    ...    ...     ...      ...    ...       ...
# 23673   False    False  False  False   True   False    False  False     False
# 23674   False    False  False  False   True   False    False  False     False
# 23675   False    False  False  False  False   False    False  False     False
# 23676   False    False  False  False  False   False    False  False     False
# 23677   False    False  False  False  False   False    False  False     False
#
# ...

# %% [markdown]
# ### Ans9. Determine the column names having more than 30% missing values and remove them from the dataset.

# %%
(df1.isnull().sum()/len(df1))*100>30
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price            False
# Method           False
# SellerG          False
# Date             False
# Distance         False
# Postcode         False
# Bedroom2         False
# Bathroom         False
# Car              False
# Landsize         False
# BuildingArea      True
# YearBuilt         True
# CouncilArea       True
# Lattitude        False
# Longtitude       False
# Regionname       False
# Propertycount    False
# dtype: bool

# %%
df1.drop(columns=['BuildingArea','YearBuilt','CouncilArea'], axis=1, inplace=True)

# %%
df1.shape
# Out:
# (23547, 18)

# %% [markdown]
# ### Ans10. Determine the number and percentage of rows having more than 5 missing values. If the percentage of such rows is less than 20% then remove all these rows.

# %%
row5_miss= df1.loc[df1.isnull().sum(axis=1)>5]

# %%
row5_miss
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 15            Abbotsford     217 Langridge St    3.0    h  1000000.0      S
# 16            Abbotsford      18a Mollison St    2.0    t   745000.0      S
# 19            Abbotsford  403/609 Victoria St    2.0    u   542000.0      S
# 21            Abbotsford    25/84 Trenerry Cr    2.0    u   760000.0     SP
# 22            Abbotsford    106/119 Turner St    1.0    u   481000.0     SP
# ...                  ...                  ...    ...  ...        ...    ...
# 23626  Templestowe Lower  1/207 Manningham Rd    2.0    u   550000.0     PI
# 23630          Thornbury      1/128 Dundas St    2.0    t   770000.0     PI
# 23633          Thornbury        111 Pender St    2.0    t   858000.0      S
# 23639             Toorak   21/1059 Malvern Rd    2.0    u   720000.0     VB
# 23662           Werribee         91 Latham St    4.0    h   540000.0     PI
#
# ...

# %%
row5_miss.shape
# Out:
# (4278, 18)

# %%
(4278/23547)*100
# Out:
# 18.16791948018856

# %% [markdown]
# Conclusion:
#     1. Row index having more than 5 null value is 4278.
#     2. Row having more than 5 null value persent is 18% and less than 20% so it drop.

# %%
df1.drop(df1[df1.isnull().sum(axis=1)>5].index,axis=0,inplace=True)

# %%
df1.shape
# Out:
# (19269, 18)

# %% [markdown]
# ### Ans11. Display the description of data and percentage of missing values still left column wise.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19269 entries, 0 to 23677
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         19269 non-null  object
#  1   Address        19269 non-null  object
#  2   Rooms          19269 non-null  float64
#  3   Type           19269 non-null  object
#  4   Price          15086 non-null  float64
#  5   Method         19269 non-null  object
#  6   SellerG        19269 non-null  object
#  7   Date           19269 non-null  object
#  8   Distance       19269 non-null  float64
#  9   Postcode       19269 non-null  float64
#  10  Bedroom2       19066 non-null  float64
#  11  Bathroom       19063 non-null  float64
#  12  Car            18921 non-null  float64
#  13  Landsize       17410 non-null  float64
#  14  Lattitude      19243 non-null  float64
#  15  Longtitude     19243 non-null  float64
#  16  Regionname     19269 non-null  object
# ...

# %%
df1.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            4183
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2          203
# Bathroom          206
# Car               348
# Landsize         1859
# Lattitude          26
# Longtitude         26
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
(df1.isnull().sum()/len(df1))*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            21.708444
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.000000
# Postcode          0.000000
# Bedroom2          1.053506
# Bathroom          1.069075
# Car               1.806010
# Landsize          9.647621
# Lattitude         0.134932
# Longtitude        0.134932
# Regionname        0.000000
# Propertycount     0.000000
# dtype: float64

# %% [markdown]
# ### Ans12. Considering the 'Price' column as target variable which is to be predicted, how will you treat the missing values? Give a brief explanation and treat the missing values in 'Price' column.

# %% [markdown]
# Observation:
#     Price column is a target column and in this column more than 20% null value so not drop all the null value of Price  columns.
#     because if drop all the null value of the price columns so drop more data it's not good way.

# %%
df1.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  19269.000000  1.508600e+04  19269.000000  19269.000000  19066.000000
# mean       2.973117  1.066695e+06     10.204365   3110.015777      2.951956
# std        0.978969  6.389331e+05      6.065786     93.730487      0.996032
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.400000e+05      6.100000   3049.000000      2.000000
# 50%        3.000000  9.000000e+05      9.200000   3102.000000      3.000000
# 75%        4.000000  1.320000e+06     13.000000   3150.000000      4.000000
# max       12.000000  9.000000e+06     48.100000   3977.000000     30.000000
#
#            Bathroom           Car       Landsize     Lattitude    Longtitude  \
# count  19063.000000  18921.000000   17410.000000  19243.000000  19243.000000
# mean       1.570897      1.626235     551.783458    -37.812434    145.000287
# ...

# %%
df1['Price'].min()
# Out:
# 85000.0

# %%
df1['Price'].max()
# Out:
# 9000000.0

# %%
df1[df1['Price'].isna()]
# Out:
#              Suburb             Address  Rooms Type  Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h    NaN     SS
# 3        Abbotsford  18/659 Victoria St    3.0    u    NaN     VB
# 7        Abbotsford        16 Maugie St    4.0    h    NaN     SN
# 8        Abbotsford        53 Turner St    2.0    h    NaN      S
# 9        Abbotsford        99 Turner St    2.0    h    NaN      S
# ...             ...                 ...    ...  ...    ...    ...
# 23660      Werribee         6 Feijoa Ct    5.0    h    NaN      W
# 23661      Werribee      11 Gundaroo Sq    4.0    h    NaN     PI
# 23664      Werribee            3 Sky Ct    3.0    h    NaN     PI
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u    NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h    NaN      S
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0             Jellis  03-09-2016       2.5    3067.0       2.0       1.0  1.0
# ...

# %%
#price column missing value fillup by mean 
df1['Price'].fillna(df1['Price'].mean(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2          203
# Bathroom          206
# Car               348
# Landsize         1859
# Lattitude          26
# Longtitude         26
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# Price column null value is filling by mean beacuse median value is very large

# %% [markdown]
# ### Ans13. Now check the percentage of missing values in each column again, if missing values exist, treat it with the most suitable method.

# %%
df1.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2          203
# Bathroom          206
# Car               348
# Landsize         1859
# Lattitude          26
# Longtitude         26
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
(df1.isnull().sum()/len(df1))*100
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.000000
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000000
# Postcode         0.000000
# Bedroom2         1.053506
# Bathroom         1.069075
# Car              1.806010
# Landsize         9.647621
# Lattitude        0.134932
# Longtitude       0.134932
# Regionname       0.000000
# Propertycount    0.000000
# dtype: float64

# %%
#traet the null value
df1.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms            float64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df1.columns[df1.isnull().any()]
# Out:
# Index(['Bedroom2', 'Bathroom', 'Car', 'Landsize', 'Lattitude', 'Longtitude'], dtype='object')

# %% [markdown]
# No null Value persent in Object type columns.

# %%
#ALL numerical columns missing value fillup by mean 
df1['Bedroom2'].fillna(df1['Bedroom2'].mean(),inplace=True)
df1['Bathroom'].fillna(df1['Bathroom'].mean(),inplace=True)

df1['Car'].fillna(df1['Car'].mean(),inplace=True)
df1['Landsize'].fillna(df1['Landsize'].mean(),inplace=True)

df1['Lattitude'].fillna(df1['Lattitude'].mean(),inplace=True)
df1['Longtitude'].fillna(df1['Longtitude'].mean(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# ### Ans14. Now since you have completed your data cleaning, determine the number and percentage of columns removed.

# %%
df.shape
# Out:
# (23678, 21)

# %%
df1.shape
# Out:
# (19269, 18)

# %% [markdown]
# Conclusion:
#     3 columns removed after data cleaning.

# %%
(3/21)*100
# Out:
# 14.285714285714285

# %% [markdown]
# ### Ans15. Determine the number and percentage of rows removed in whole process. Also comment briefly that according to you the amount of data lost is justified or not.

# %%
df.shape
# Out:
# (23678, 21)

# %%
df1.shape
# Out:
# (19269, 18)

# %%
23678-19269
# Out:
# 4409

# %% [markdown]
# 4409 rows removed in whole process.

# %%
(4409/23678)*100
# Out:
# 18.620660528760872

# %% [markdown]
# ### 4409 rows and 18% of row removed in whole data cleaning process.data lost is more than 10%  its not good But in this dataset lots of null value persent and not drop any neccesary data. So not lossing information. According to me in this dataset less than 25% data lost and is justified.
